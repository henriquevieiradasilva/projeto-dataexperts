# %% [markdown]
# # Gold Layer

# %% [markdown]
# ## Configuração do servidor para trabalho no Gold Layer

# %% [markdown]
# ## Trabalhos no Gold Layer

# %% [markdown]
# ## Salvar arquivos na camada Gold

# %% [markdown]
# ## Limpar Memória
